# %% [markdown]
# Data extraction
#
# The second step in the NLP pipeline is extracting the text from its native form (such as pdf, image or html files).
#
# Our dataset is a CSV(Comma Separated Values) file that contains tweets data. Each row contains the text of a tweet and a sentiment label. We will use the Pandas library to read the CSV file and load data into a dataframe.
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.11/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.11/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.11/dist-packages (from textsearch>=0.0.21->contractions) (0.3.3)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.11/dist-packages (from textsearch>=0.0.21->contractions) (2.2.0)

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (2.14.1)

# %%
import requests
url = "https://raw.githubusercontent.com/ezzybala/NLP-pipeline-Tweeter-Sentiment-Analysis/refs/heads/main/dataset/train_tweets.csv"
file_name = "train_tweets.csv"

response = requests.get(url)
if response.status_code == 200:
    with open(file_name, "wb") as file:
        file.write(response.content)
        print(f"File {file_name} downloaded successfully.")
else:
    print("Failed to download the file.")
# Out:
# File train_tweets.csv downloaded successfully.

# %%
import pandas as pd
#load the csv file in a dataframe
raw_data = pd.read_csv("train_tweets.csv")

raw_data.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
print(raw_data.shape)
# Out:
# (31962, 3)

# %%
# rearrange the columns in the training dataset
# and remove the id column
train_df = raw_data[['tweet', 'label']]
train_df.columns = ['tweet', 'sentiment']
train_df.head()
# Out:
#                                                tweet  sentiment
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0

# %%
train_df.sentiment.value_counts()
# Out:
# sentiment
# 0    29720
# 1     2242
# Name: count, dtype: int64

# %%
# define a dictionary to map numbers to corresponding sentiments
map = {0: 'Positive', 1: 'Negative'}

# %%
import emoji
def fix_encoding(text):
    try:
        return text.encode('latin1').decode('utf-8')
    except (UnicodeEncodeError, UnicodeDecodeError):
        return text

# 2. Convert emoji to text meaning
def emoji_to_words(text):
    return emoji.demojize(text, delimiters=(" ", " "))  # 😜 → face_with_stuck_out_tongue_winking_eye

# %% [markdown]
# In order to clean the text of tweets, we will first create a function that lowercase text, expand contractions, removes text enclosed in square brackets, removes links, removes punctuation, and removes words containing numbers.
#
# For Cleaning, we performed the following:
# *   Make text lowercase
# *   Expand contractions
# *   Remove text in square brackets
# *   Removed Links
# *   Removed puntuations
# *   Removed new lines
# *   Removed words containing numbers

# %%
import re
from string import punctuation
import contractions

def clean_text(text, keep_emojis=False):
    text = fix_encoding(text)
    # make text lowercase
    text = str(text).lower()
    # expand contractions
    text = " ".join([contractions.fix(expanded_word) for expanded_word in text.split()])
    # remove text in square brackets
    text = re.sub('\[.*?\]', '', text)
    # remove links
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    # remove punctuation
    text = re.sub('[%s]' % re.escape(punctuation), '', text)
    # remove new lines
    text = re.sub('\n', '', text)
    # remove words containing numbers
    text = re.sub('\w*\d\w*', '', text)
    # Step 5: Convert emoji to words (optional)
    if not keep_emojis:
        text = emoji_to_words(text)
    return text

# %%
# apply clean text fuction on each twitte in the training dataset
train_df['clean_tweet'] = train_df['tweet'].apply(lambda x: clean_text(x))

train_df.head()
# Out:
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet
# 0  user when a father is dysfunctional and is so ...
# 1  user user thanks for lyft credit i cannot use ...
# 2                                bihday your majesty
# 3  model i love you take with you all the time in...
# 4                  factsguide society now motivation

# %%
train_df.to_csv('clean_tweets.csv', index=False)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

train_df['tokenized_sents'] = train_df['clean_tweet'].apply(lambda x: len(sent_tokenize(x)))
train_df.head()
# Out:
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet  tokenized_sents
# 0  user when a father is dysfunctional and is so ...                1
# 1  user user thanks for lyft credit i cannot use ...                1
# 2                                bihday your majesty                1
# 3  model i love you take with you all the time in...                1
# 4                  factsguide society now motivation                1

# %%
from nltk.tokenize import word_tokenize

train_df['word_list'] = train_df['clean_tweet'].apply(lambda x:word_tokenize(str(x)))
train_df.head()
# Out:
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet  tokenized_sents  \
# 0  user when a father is dysfunctional and is so ...                1
# 1  user user thanks for lyft credit i cannot use ...                1
# 2                                bihday your majesty                1
# 3  model i love you take with you all the time in...                1
# 4                  factsguide society now motivation                1
#
#                                            word_list
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]

# %%
from collections import Counter

top = Counter([item for sublist in train_df['word_list'] for item in sublist])
temp_df = pd.DataFrame(top.most_common(20))
temp_df.columns = ['Common_words','count']
temp_df.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_3ef51_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3ef51_row1_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_3ef51_row2_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_3ef51_row3_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_3ef51_row4_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_3ef51_row5_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_3ef51_row6_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_3ef51_row7_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3ef51_row8_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_3ef51_row9_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_3ef51_row10_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3ef51_row11_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3ef51_row12_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_3ef51_row13_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_3ef51_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3ef51_row15_col1, #T_3ef51_row16_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3ef51_row17_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3ef51_row18_col1, #T_3ef51_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_3ef51" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ef51_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_3ef51_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ef51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ef51_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_3ef51_row0_col1" class="data row0 col1" >17506</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ef51_row1_col0" class="data row1 col0" >the</td>
#       <td id="T_3ef51_row1_col1" class="data row1 col1" >10182</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ef51_row2_col0" class="data row2 col0" >to</td>
#       <td id="T_3ef51_row2_col1" class="data row2 col1" >10094</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ef51_row3_col0" class="data row3 col0" >you</td>
#       <td id="T_3ef51_row3_col1" class="data row3 col1" >7560</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ef51_row4_col0" class="data row4 col0" >i</td>
#       <td id="T_3ef51_row4_col1" class="data row4 col1" >7325</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ef51_row5_col0" class="data row5 col0" >a</td>
#       <td id="T_3ef51_row5_col1" class="data row5 col1" >6422</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ef51_row6_col0" class="data row6 col0" >is</td>
#       <td id="T_3ef51_row6_col1" class="data row6 col1" >6164</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ef51_row7_col0" class="data row7 col0" >and</td>
#       <td id="T_3ef51_row7_col1" class="data row7 col1" >4875</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ef51_row8_col0" class="data row8 col0" >in</td>
#       <td id="T_3ef51_row8_col1" class="data row8 col1" >4644</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ef51_row9_col0" class="data row9 col0" >for</td>
#       <td id="T_3ef51_row9_col1" class="data row9 col1" >4484</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3ef51_row10_col0" class="data row10 col0" >of</td>
#       <td id="T_3ef51_row10_col1" class="data row10 col1" >4193</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3ef51_row11_col0" class="data row11 col0" >not</td>
#       <td id="T_3ef51_row11_col1" class="data row11 col1" >3782</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3ef51_row12_col0" class="data row12 col0" >my</td>
#       <td id="T_3ef51_row12_col1" class="data row12 col1" >3681</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3ef51_row13_col0" class="data row13 col0" >it</td>
#       <td id="T_3ef51_row13_col1" class="data row13 col1" >3598</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3ef51_row14_col0" class="data row14 col0" >are</td>
#       <td id="T_3ef51_row14_col1" class="data row14 col1" >3014</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3ef51_row15_col0" class="data row15 col0" >love</td>
#       <td id="T_3ef51_row15_col1" class="data row15 col1" >2697</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3ef51_row16_col0" class="data row16 col0" >this</td>
#       <td id="T_3ef51_row16_col1" class="data row16 col1" >2661</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3ef51_row17_col0" class="data row17 col0" >on</td>
#       <td id="T_3ef51_row17_col1" class="data row17 col1" >2634</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3ef51_row18_col0" class="data row18 col0" >with</td>
#       <td id="T_3ef51_row18_col1" class="data row18 col1" >2513</td>
#     </tr>
#     <tr>
#       <th id="T_3ef51_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3ef51_row19_col0" class="data row19 col0" >be</td>
#       <td id="T_3ef51_row19_col1" class="data row19 col1" >2467</td>
#     </tr>
#   </tbody>
# </table>

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def remove_stopword(word_list):
  return [word for word in word_list if word not in stopwords.words('english')]

train_df['word_list_without_sw'] = train_df['word_list'].apply(lambda x:remove_stopword(x))

# %%
train_df.head()
# Out:
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet  tokenized_sents  \
# 0  user when a father is dysfunctional and is so ...                1
# 1  user user thanks for lyft credit i cannot use ...                1
# 2                                bihday your majesty                1
# 3  model i love you take with you all the time in...                1
# 4                  factsguide society now motivation                1
#
#                                            word_list  \
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]
#
#                                 word_list_without_sw
# 0  [user, father, dysfunctional, selfish, drags, ...
# 1  [user, user, thanks, lyft, credit, use, offer,...
# 2                                  [bihday, majesty]
# 3  [model, love, take, time, mobile_phone, kissin...
# 4                  [factsguide, society, motivation]

# %%
top = Counter([item for sublist in train_df['word_list_without_sw'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns=['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_2814d_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_2814d_row1_col1 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_2814d_row2_col1 {
#   background-color: #a4a1cc;
#   color: #f1f1f1;
# }
# #T_2814d_row3_col1 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_2814d_row4_col1 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_2814d_row5_col1 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_2814d_row6_col1 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_2814d_row7_col1 {
#   background-color: #eeecf4;
#   color: #000000;
# }
# #T_2814d_row8_col1, #T_2814d_row9_col1 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_2814d_row10_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_2814d_row11_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_2814d_row12_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_2814d_row13_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_2814d_row14_col1, #T_2814d_row15_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_2814d_row16_col1, #T_2814d_row17_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_2814d_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_2814d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2814d_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_2814d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2814d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2814d_row0_col0" class="data row0 col0" >love</td>
#       <td id="T_2814d_row0_col1" class="data row0 col1" >2697</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2814d_row1_col0" class="data row1 col0" >day</td>
#       <td id="T_2814d_row1_col1" class="data row1 col1" >2244</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2814d_row2_col0" class="data row2 col0" >happy</td>
#       <td id="T_2814d_row2_col1" class="data row2 col1" >1690</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2814d_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_2814d_row3_col1" class="data row3 col1" >1586</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2814d_row4_col0" class="data row4 col0" >time</td>
#       <td id="T_2814d_row4_col1" class="data row4 col1" >1122</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2814d_row5_col0" class="data row5 col0" >…</td>
#       <td id="T_2814d_row5_col1" class="data row5 col1" >1113</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2814d_row6_col0" class="data row6 col0" >life</td>
#       <td id="T_2814d_row6_col1" class="data row6 col1" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2814d_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_2814d_row7_col1" class="data row7 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2814d_row8_col0" class="data row8 col0" >today</td>
#       <td id="T_2814d_row8_col1" class="data row8 col1" >1003</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_2814d_row9_col0" class="data row9 col0" >sweat_droplets</td>
#       <td id="T_2814d_row9_col1" class="data row9 col1" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_2814d_row10_col0" class="data row10 col0" >new</td>
#       <td id="T_2814d_row10_col1" class="data row10 col1" >985</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_2814d_row11_col0" class="data row11 col0" >people</td>
#       <td id="T_2814d_row11_col1" class="data row11 col1" >959</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_2814d_row12_col0" class="data row12 col0" >red_heart</td>
#       <td id="T_2814d_row12_col1" class="data row12 col1" >937</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_2814d_row13_col0" class="data row13 col0" >positive</td>
#       <td id="T_2814d_row13_col1" class="data row13 col1" >928</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_2814d_row14_col0" class="data row14 col0" >thankful</td>
#       <td id="T_2814d_row14_col1" class="data row14 col1" >920</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_2814d_row15_col0" class="data row15 col0" >get</td>
#       <td id="T_2814d_row15_col1" class="data row15 col1" >918</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_2814d_row16_col0" class="data row16 col0" >bihday</td>
#       <td id="T_2814d_row16_col1" class="data row16 col1" >846</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_2814d_row17_col0" class="data row17 col0" >good</td>
#       <td id="T_2814d_row17_col1" class="data row17 col1" >846</td>
#     </tr>
#     <tr>
#       <th id="T_2814d_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_2814d_row18_col0" class="data row18 col0" >one</td>
#       <td id="T_2814d_row18_col1" class="data row18 col1" >783</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df
# Out:
#                                                    tweet  sentiment  \
# 0       @user when a father is dysfunctional and is s...          0
# 1      @user @user thanks for #lyft credit i can't us...          0
# 2                                    bihday your majesty          0
# 3      #model   i love u take with u all the time in ...          0
# 4                 factsguide: society now    #motivation          0
# ...                                                  ...        ...
# 31957  ate @user isz that youuu?ðððððð...          0
# 31958    to see nina turner on the airwaves trying to...          0
# 31959  listening to sad songs on a monday morning otw...          0
# 31960  @user #sikh #temple vandalised in in #calgary,...          1
# 31961                   thank you @user for you follow            0
#
#                                              clean_tweet  tokenized_sents  \
# 0      user when a father is dysfunctional and is so ...                1
# 1      user user thanks for lyft credit i cannot use ...                1
# 2                                    bihday your majesty                1
# 3      model i love you take with you all the time in...                1
# 4                      factsguide society now motivation                1
# ...                                                  ...              ...
# 31957  ate user isz that youuu smiling_face_with_hear...                1
# 31958  to see nina turner on the airwaves trying to w...                1
# 31959  listening to sad songs on a monday morning otw...                1
# 31960  user sikh temple vandalised in in calgary wso ...                1
# 31961                      thank you user for you follow                1
#
#                                                word_list  \
# 0      [user, when, a, father, is, dysfunctional, and...
# 1      [user, user, thanks, for, lyft, credit, i, can...
# 2                                [bihday, your, majesty]
# 3      [model, i, love, you, take, with, you, all, th...
# 4                 [factsguide, society, now, motivation]
# ...                                                  ...
# 31957  [ate, user, isz, that, youuu, smiling_face_wit...
# 31958  [to, see, nina, turner, on, the, airwaves, try...
# 31959  [listening, to, sad, songs, on, a, monday, mor...
# 31960  [user, sikh, temple, vandalised, in, in, calga...
# 31961               [thank, you, user, for, you, follow]
#
#                                     word_list_without_sw
# 0      [user, father, dysfunctional, selfish, drags, ...
# 1      [user, user, thanks, lyft, credit, use, offer,...
# 2                                      [bihday, majesty]
# 3      [model, love, take, time, mobile_phone, kissin...
# 4                      [factsguide, society, motivation]
# ...                                                  ...
# 31957  [ate, user, isz, youuu, smiling_face_with_hear...
# 31958  [see, nina, turner, airwaves, trying, wrap, ma...
# 31959  [listening, sad, songs, monday, morning, otw, ...
# 31960  [user, sikh, temple, vandalised, calgary, wso,...
# 31961                              [thank, user, follow]
#
# [31962 rows x 6 columns]

# %%
positive_tweets = train_df[train_df['sentiment'] == 0]
negative_tweets = train_df[train_df['sentiment'] == 1]

# %%
# Most common positive words
top = Counter([item for sublist in positive_tweets['word_list_without_sw'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_positive_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_53755_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_53755_row1_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_53755_row2_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_53755_row3_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_53755_row4_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_53755_row5_col1, #T_53755_row6_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_53755_row7_col1, #T_53755_row8_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_53755_row9_col1, #T_53755_row10_col1, #T_53755_row11_col1, #T_53755_row12_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_53755_row13_col1, #T_53755_row14_col1, #T_53755_row15_col1, #T_53755_row16_col1, #T_53755_row17_col1, #T_53755_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_53755_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_53755" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53755_level0_col0" class="col_heading level0 col0" >Common_positive_words</th>
#       <th id="T_53755_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53755_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53755_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_53755_row0_col1" class="data row0 col1" >15644</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53755_row1_col0" class="data row1 col0" >love</td>
#       <td id="T_53755_row1_col1" class="data row1 col1" >2672</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53755_row2_col0" class="data row2 col0" >day</td>
#       <td id="T_53755_row2_col1" class="data row2 col1" >2236</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_53755_row3_col0" class="data row3 col0" >happy</td>
#       <td id="T_53755_row3_col1" class="data row3 col1" >1678</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_53755_row4_col0" class="data row4 col0" >amp</td>
#       <td id="T_53755_row4_col1" class="data row4 col1" >1318</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_53755_row5_col0" class="data row5 col0" >time</td>
#       <td id="T_53755_row5_col1" class="data row5 col1" >1100</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_53755_row6_col0" class="data row6 col0" >life</td>
#       <td id="T_53755_row6_col1" class="data row6 col1" >1096</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_53755_row7_col0" class="data row7 col0" >sweat_droplets</td>
#       <td id="T_53755_row7_col1" class="data row7 col1" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_53755_row8_col0" class="data row8 col0" >today</td>
#       <td id="T_53755_row8_col1" class="data row8 col1" >991</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_53755_row9_col0" class="data row9 col0" >red_heart</td>
#       <td id="T_53755_row9_col1" class="data row9 col1" >931</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_53755_row10_col0" class="data row10 col0" >positive</td>
#       <td id="T_53755_row10_col1" class="data row10 col1" >925</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_53755_row11_col0" class="data row11 col0" >thankful</td>
#       <td id="T_53755_row11_col1" class="data row11 col1" >920</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_53755_row12_col0" class="data row12 col0" >new</td>
#       <td id="T_53755_row12_col1" class="data row12 col1" >916</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_53755_row13_col0" class="data row13 col0" >like</td>
#       <td id="T_53755_row13_col1" class="data row13 col1" >907</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_53755_row14_col0" class="data row14 col0" >…</td>
#       <td id="T_53755_row14_col1" class="data row14 col1" >906</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_53755_row15_col0" class="data row15 col0" >get</td>
#       <td id="T_53755_row15_col1" class="data row15 col1" >884</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_53755_row16_col0" class="data row16 col0" >people</td>
#       <td id="T_53755_row16_col1" class="data row16 col1" >854</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_53755_row17_col0" class="data row17 col0" >bihday</td>
#       <td id="T_53755_row17_col1" class="data row17 col1" >846</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_53755_row18_col0" class="data row18 col0" >good</td>
#       <td id="T_53755_row18_col1" class="data row18 col1" >813</td>
#     </tr>
#     <tr>
#       <th id="T_53755_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_53755_row19_col0" class="data row19 col0" >one</td>
#       <td id="T_53755_row19_col1" class="data row19 col1" >735</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Most common negative words
top = Counter([item for sublist in negative_tweets['word_list_without_sw'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_negative_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_244a3_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_244a3_row1_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_244a3_row2_col1 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_244a3_row3_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_244a3_row4_col1, #T_244a3_row5_col1 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_244a3_row6_col1 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_244a3_row7_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_244a3_row8_col1 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_244a3_row9_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_244a3_row10_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_244a3_row11_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_244a3_row12_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_244a3_row13_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_244a3_row14_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_244a3_row15_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_244a3_row16_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_244a3_row17_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_244a3_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_244a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_244a3_level0_col0" class="col_heading level0 col0" >Common_negative_words</th>
#       <th id="T_244a3_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_244a3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_244a3_row0_col0" class="data row0 col0" >amp</td>
#       <td id="T_244a3_row0_col1" class="data row0 col1" >268</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_244a3_row1_col0" class="data row1 col0" >…</td>
#       <td id="T_244a3_row1_col1" class="data row1 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_244a3_row2_col0" class="data row2 col0" >trump</td>
#       <td id="T_244a3_row2_col1" class="data row2 col1" >201</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_244a3_row3_col0" class="data row3 col0" >libtard</td>
#       <td id="T_244a3_row3_col1" class="data row3 col1" >149</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_244a3_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_244a3_row4_col1" class="data row4 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_244a3_row5_col0" class="data row5 col0" >white</td>
#       <td id="T_244a3_row5_col1" class="data row5 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_244a3_row6_col0" class="data row6 col0" >black</td>
#       <td id="T_244a3_row6_col1" class="data row6 col1" >131</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_244a3_row7_col0" class="data row7 col0" >people</td>
#       <td id="T_244a3_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_244a3_row8_col0" class="data row8 col0" >racist</td>
#       <td id="T_244a3_row8_col1" class="data row8 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_244a3_row9_col0" class="data row9 col0" >politics</td>
#       <td id="T_244a3_row9_col1" class="data row9 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_244a3_row10_col0" class="data row10 col0" >allahsoil</td>
#       <td id="T_244a3_row10_col1" class="data row10 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_244a3_row11_col0" class="data row11 col0" >liberal</td>
#       <td id="T_244a3_row11_col1" class="data row11 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_244a3_row12_col0" class="data row12 col0" >might</td>
#       <td id="T_244a3_row12_col1" class="data row12 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_244a3_row13_col0" class="data row13 col0" >sjw</td>
#       <td id="T_244a3_row13_col1" class="data row13 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_244a3_row14_col0" class="data row14 col0" >women</td>
#       <td id="T_244a3_row14_col1" class="data row14 col1" >72</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_244a3_row15_col0" class="data row15 col0" >new</td>
#       <td id="T_244a3_row15_col1" class="data row15 col1" >69</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_244a3_row16_col0" class="data row16 col0" >obama</td>
#       <td id="T_244a3_row16_col1" class="data row16 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_244a3_row17_col0" class="data row17 col0" >us</td>
#       <td id="T_244a3_row17_col1" class="data row17 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_244a3_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_244a3_row18_col0" class="data row18 col0" >hate</td>
#       <td id="T_244a3_row18_col1" class="data row18 col1" >65</td>
#     </tr>
#   </tbody>
# </table>

# %%
nltk.download("wordnet")
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
train_df['word_list_without_sw'] = train_df['word_list_without_sw'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
train_df.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet  tokenized_sents  \
# 0  user when a father is dysfunctional and is so ...                1
# 1  user user thanks for lyft credit i cannot use ...                1
# 2                                bihday your majesty                1
# 3  model i love you take with you all the time in...                1
# 4                  factsguide society now motivation                1
#
#                                            word_list  \
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]
#
#                                 word_list_without_sw
# 0  [user, father, dysfunctional, selfish, drag, k...
# 1  [user, user, thanks, lyft, credit, use, offer,...
# 2                                  [bihday, majesty]
# 3  [model, love, take, time, mobile_phone, kissin...
# 4                  [factsguide, society, motivation]

# %%
train_df['final_tweet'] = train_df['word_list_without_sw'].apply(lambda x:' '.join(x))
train_df.head()
# Out:
#                                                tweet  sentiment  \
# 0   @user when a father is dysfunctional and is s...          0
# 1  @user @user thanks for #lyft credit i can't us...          0
# 2                                bihday your majesty          0
# 3  #model   i love u take with u all the time in ...          0
# 4             factsguide: society now    #motivation          0
#
#                                          clean_tweet  tokenized_sents  \
# 0  user when a father is dysfunctional and is so ...                1
# 1  user user thanks for lyft credit i cannot use ...                1
# 2                                bihday your majesty                1
# 3  model i love you take with you all the time in...                1
# 4                  factsguide society now motivation                1
#
#                                            word_list  \
# 0  [user, when, a, father, is, dysfunctional, and...
# 1  [user, user, thanks, for, lyft, credit, i, can...
# 2                            [bihday, your, majesty]
# 3  [model, i, love, you, take, with, you, all, th...
# 4             [factsguide, society, now, motivation]
#
#                                 word_list_without_sw  \
# 0  [user, father, dysfunctional, selfish, drag, k...
# 1  [user, user, thanks, lyft, credit, use, offer,...
# 2                                  [bihday, majesty]
# 3  [model, love, take, time, mobile_phone, kissin...
# 4                  [factsguide, society, motivation]
#
#                                          final_tweet
# 0  user father dysfunctional selfish drag kid dys...
# 1  user user thanks lyft credit use offer wheelch...
# 2                                     bihday majesty
# 3  model love take time mobile_phone kissing_face...
# 4                      factsguide society motivation

# %%
train_df.to_csv('processed_train_tweets.csv', index=False)
